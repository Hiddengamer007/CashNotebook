# %%
# !curl -L -o /kaggle/working/bitcoin-datasetintervals-of-1-minute.zip\
  https://www.kaggle.com/api/v1/datasets/download/bhadramohit/bitcoin-datasetintervals-of-1-minute
# !curl -L https://raw.githubusercontent.com/Hiddengamer007/CashNotebook/refs/heads/main/crypto_predictor.py -o crypto_predictor.py
# !unzip /kaggle/working/bitcoin-datasetintervals-of-1-minute.zip
# !rm bitcoin-datasetintervals-of-1-minute.zip

# %%
# !python crypto_predictor.py --data /kaggle/working/btcusd_1-min_data.csv

# %%
# !rm crypto_predictor.py
